# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm_notebook as tqdm
import frgtools.plotting as frgplt
import seaborn as sns
from mpl_toolkits.axes_grid1 import AxesGrid

# %%
allx = []
ally = []
for f in fids:
    allx.append(float(f.split('X')[-1].split('_')[1]))
    ally.append(float(f.split('Y')[-1].split('_')[1]))

allx = np.array(allx)
ally = np.array(ally)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-c9d9299ca97f> in <module>
#       1 allx = []
#       2 ally = []
# ----> 3 for f in fids:
#       4     allx.append(float(f.split('X')[-1].split('_')[1]))
#       5     ally.append(float(f.split('Y')[-1].split('_')[1]))
#
# NameError: name 'fids' is not defined

# %%
x = np.unique(allx)
y = np.unique(ally)
x.sort()
y.sort()

# %%
temp = np.loadtxt(os.path.join(dataDir, fids[0]))
wl = shift_to_nm(temp[:,0])

# %%
a = [1,2,3]
b = ['ab', 'cd', 'ef']

for a_, b_ in zip(a, b):
    print('{}:{}'.format(a_,b_))
# Out:
# 1:ab
# 2:cd
# 3:ef

# %%
cts = np.zeros((len(y), len(x), len(wl)))
for f, x_, y_ in zip(fids, allx, ally):
    m = np.where(y == y_)
    n = np.where(x == x_)
    cts[m,n] = np.loadtxt(os.path.join(dataDir, f))[:,1]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-126c2b46d3f9> in <module>
# ----> 1 cts = np.zeros((len(y), len(x), len(wl)))
#       2 for f, x_, y_ in zip(fids, allx, ally):
#       3     m = np.where(y == y_)
#       4     n = np.where(x == x_)
#       5     cts[m,n] = np.loadtxt(os.path.join(dataDir, f))[:,1]
#
# NameError: name 'y' is not defined

# %%
def shift_to_nm(shift, incident_wl = 633):
    incident_wn = 1/(incident_wl * 1e-7)
    exit_wn = incident_wn - shift
    return 1e7/exit_wn 

def loadRenishaw(path, incident_wl = 633):
    fids = [os.path.join(path, x) for x in os.listdir(path)]
    allx = []
    ally = []
    for f in fids:
        allx.append(float(f.split('X')[-1].split('_')[1]))
        ally.append(float(f.split('Y')[-1].split('_')[1]))
    allx = np.array(allx)
    ally = np.array(ally)
    x = np.unique(allx)
    y = np.unique(ally)
    x.sort()
    y.sort()
    
    temp = np.loadtxt(fids[0])
    wl = shift_to_nm(temp[:,0], incident_wl = incident_wl)
    
    cts = np.zeros((len(y), len(x), len(wl)))
    for f, x_, y_ in tqdm(zip(fids, allx, ally), total = len(fids)):
        m = np.where(y == y_)
        n = np.where(x == x_)
        cts[m,n] = np.loadtxt(f)[:,1]    
    
    extent = [x[0], x[-1], y[0], y[-1]]
    return wl, cts, extent

# %%
cd /Users/deniz/Documents/PythonScripts/SPA/20200220_HTLPassivation_MK
# Out:
# /Users/deniz/Documents/PythonScripts/SPA/20200220_HTLPassivation_MK

# %%
wl, control, extent_control = loadRenishaw('Control-5x')
wl, topo, extent_topo = loadRenishaw('TOPO-5x')
wl, to, extent_to = loadRenishaw('TO-5x')
# Out:
# /opt/anaconda3/envs/ds/lib/python3.7/site-packages/ipykernel_launcher.py:24: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0, max=676.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=676.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=676.0), HTML(value='')))

# %%
control.shape
# Out:
# (26, 26, 1015)

# %%
fig, ax = plt.subplots(1,3, figsize = (12,5))
for ax_, im_, label_, ext_ in zip(ax, [control, topo, to], ['Control', 'TOPO', 'Theophylline'], [extent_control, extent_topo, extent_to]):
    temp = ax_.imshow(
        im_[3:-3, 3:-3].max(axis = 2),
        vmin = 30000,
        vmax = 46000,
        extent = ext_
    )
    ax_.set_title(label_)
    ax_.set_xticks([])
    ax_.set_yticks([])
    frgplt.Scalebar(ax_, scale = 1e-6)

cb = plt.colorbar(temp, ax = ax[-1], fraction = 0.046)
cb.set_label('Peak Intensity (cts)')
plt.savefig('Initial SPA Controls I', dpi = 300, bbox_inches = 'tight')

plt.show()

fig, ax = plt.subplots(1,3, figsize = (12,5))
for ax_, im_, label_, ext_ in zip(ax, [control, topo, to], ['Control', 'TOPO', 'Theophylline'],  [extent_control, extent_topo, extent_to]):
    temp = ax_.imshow(
        wl[np.argmax(im_[3:-3, 3:-3], axis = 2)],
        vmin = 760,
        vmax = 770,
        cmap = plt.cm.inferno,
        extent = ext_
    )
    frgplt.Scalebar(ax_, scale = 1e-6)
    ax_.set_title(label_)
    ax_.set_xticks([])
    ax_.set_yticks([])
cb = plt.colorbar(temp, ax = ax[-1], fraction = 0.046)
cb.set_label('Peak Wavelength (nm)')
plt.savefig('Initial SPA Controls WL', dpi = 300, bbox_inches = 'tight')
plt.show()

# %%
plt.plot(wl, control.sum(axis = (0,1)), label = 'Control')
plt.plot(wl, to.sum(axis = (0,1)), label = 'Theophylline')
plt.plot(wl, topo.sum(axis = (0,1)), label = 'TOPO')
plt.legend()
plt.savefig('Initial SPA Controls SumI', dpi = 300, bbox_inches = 'tight')

# %%
# sns.kdeplot(control[3:-3, 3:-3].max(axis = 2).ravel(), kernel = 'gau', bw = 100, label = 'Control')
# sns.kdeplot(topo[3:-3, 3:-3].max(axis = 2).ravel(), kernel = 'gau', bw = 100, label = 'TOPO')
# sns.kdeplot(to[3:-3, 3:-3].max(axis = 2).ravel(), kernel = 'gau', bw = 100, label = 'Theophyline')

# plt.legend()
# plt.xlabel('Peak Intensity (cts)')
# plt.ylabel('%')
# plt.xlim((30000, 45000))
# plt.show()

# %%
sns.kdeplot(wl[np.argmax(control[3:-3, 3:-3], axis = 2)].ravel(), kernel = 'gau', bw = 2, label = 'Control')
sns.kdeplot(wl[np.argmax(topo[3:-3, 3:-3], axis = 2)].ravel(), kernel = 'gau', bw = 2, label = 'TOPO')
sns.kdeplot(wl[np.argmax(to[3:-3, 3:-3], axis = 2)].ravel(), kernel = 'gau', bw = 2, label = 'Theophylline')

plt.legend()
plt.xlabel('Peak Wavelength (nm)')
plt.ylabel('%')
plt.xlim((750, 800))
plt.show()

# %%
import scipy

for x, l in zip([control, topo, to], ['Control', 'TOPO', 'TO']):
    plt.scatter(
        x[3:-3, 3:-3].max(axis = 2).ravel(),
        wl[np.argmax(x[3:-3, 3:-3], axis = 2)].ravel(),
        label = l,
        s = 3
    )
plt.legend()
plt.xlabel('Peak Intensity (cts)')
plt.ylabel('Peak Wavelength (nm)')
plt.xlim(left = 20000)
plt.ylim((755, 770))
plt.show()
